# %% [markdown]
# Importem llibreries y gràfica

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importem DF

# %%
RRHH = pd.read_csv(r"C:\Users\PC\Desktop\ProjecteData\Equip_15\Data\RRHH_220925_clean.csv")

# %% [markdown]
# Insertem diccionari que utilitzarem

# %%
reason_absence_dict = {
    0: "Sin especificar / Otros",
    1: "Enfermedades infecciosas y parasitarias",
    2: "Neoplasias (tumores)",
    3: "Enfermedades de la sangre y órganos hematopoyéticos",
    4: "Enfermedades endocrinas, nutricionales y metabólicas",
    5: "Trastornos mentales y del comportamiento",
    6: "Enfermedades del sistema nervioso",
    7: "Enfermedades del ojo y sus anexos",
    8: "Enfermedades del oído y la apófisis mastoides",
    9: "Enfermedades del sistema circulatorio",
    10: "Enfermedades del sistema respiratorio",
    11: "Enfermedades del sistema digestivo",
    12: "Enfermedades de la piel y tejido subcutáneo",
    13: "Enfermedades del sistema musculoesquelético y tejido conectivo",
    14: "Enfermedades del sistema genitourinario",
    15: "Embarazo, parto y puerperio",
    16: "Condiciones originadas en el período perinatal",
    17: "Malformaciones congénitas y anomalías cromosómicas",
    18: "Síntomas y signos no clasificados",
    19: "Lesiones, envenenamientos y consecuencias de otras causas externas",
    20: "Causas externas de morbilidad y mortalidad",
    21: "Factores que influyen en el estado de salud",
    22: "Paciente en seguimiento",
    23: "Consulta médica",
    24: "Donación de sangre",
    25: "Examen de laboratorio",
    26: "Ausencia injustificada",
    27: "Fisioterapia",
    28: "Consulta dental"
}

# %% [markdown]
# 1. Porcentaje de empleados ausentes (%) = (Número de empleados que tuvieron al menos 1 ausencia DIVIDIDO Número total de empleados ) x 100

# %%
# Calcular total de horas de absentismo anual
total_hores_abs = RRHH['Absenteeism_hours'].sum()

# Calcular total de empleados únicos
total_empleados = RRHH['ID'].nunique()

# Filtrar solo empleados con ausencias reales (horas > 0)
empleados_con_ausencia_real = RRHH[RRHH['Absenteeism_hours'] > 0]['ID'].nunique()

# Calcular el porcentaje de empleados ausentes
porcentaje_ausentes = (empleados_con_ausencia_real / total_empleados) * 100

# Mostrar los resultados
print("="*50)
print("ESTADÍSTICAS DE ABSENTISMO")
print("="*50)
print(f"Total horas absentismo anual: {total_hores_abs:.2f}")
print(f"Total empleados únicos: {total_empleados}")
print(f"✅ Porcentaje de empleados ausentes: {porcentaje_ausentes:.2f}%")
print(f"   - Empleados totales en dataset: {total_empleados}")
print(f"   - Empleados con ausencias reales: {empleados_con_ausencia_real}")
print("="*50)
# Out:
# ==================================================
# ESTADÍSTICAS DE ABSENTISMO
# ==================================================
# Total horas absentismo anual: 5856.00
# Total empleados únicos: 136
# ✅ Porcentaje de empleados ausentes: 94.85%
#    - Empleados totales en dataset: 136
#    - Empleados con ausencias reales: 129
# ==================================================

# %% [markdown]
# Importem llibreries y gràfica

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importem DF

# %%
RRHH = pd.read_csv(r"C:\Users\PC\Desktop\ProjecteData\Equip_15\Data\RRHH_220925_clean.csv")

# %% [markdown]
# Insertem diccionari que utilitzarem

# %%
reason_absence_dict = {
    0: "Sin especificar / Otros",
    1: "Enfermedades infecciosas y parasitarias",
    2: "Neoplasias (tumores)",
    3: "Enfermedades de la sangre y órganos hematopoyéticos",
    4: "Enfermedades endocrinas, nutricionales y metabólicas",
    5: "Trastornos mentales y del comportamiento",
    6: "Enfermedades del sistema nervioso",
    7: "Enfermedades del ojo y sus anexos",
    8: "Enfermedades del oído y la apófisis mastoides",
    9: "Enfermedades del sistema circulatorio",
    10: "Enfermedades del sistema respiratorio",
    11: "Enfermedades del sistema digestivo",
    12: "Enfermedades de la piel y tejido subcutáneo",
    13: "Enfermedades del sistema musculoesquelético y tejido conectivo",
    14: "Enfermedades del sistema genitourinario",
    15: "Embarazo, parto y puerperio",
    16: "Condiciones originadas en el período perinatal",
    17: "Malformaciones congénitas y anomalías cromosómicas",
    18: "Síntomas y signos no clasificados",
    19: "Lesiones, envenenamientos y consecuencias de otras causas externas",
    20: "Causas externas de morbilidad y mortalidad",
    21: "Factores que influyen en el estado de salud",
    22: "Paciente en seguimiento",
    23: "Consulta médica",
    24: "Donación de sangre",
    25: "Examen de laboratorio",
    26: "Ausencia injustificada",
    27: "Fisioterapia",
    28: "Consulta dental"
}

# %% [markdown]
# 1. Porcentaje de empleados ausentes (%) = (Número de empleados que tuvieron al menos 1 ausencia DIVIDIDO Número total de empleados ) x 100

# %%
# Calcular total de horas de absentismo anual
total_hores_abs = RRHH['Absenteeism_hours'].sum()

# Calcular total de empleados únicos en el dataset
total_empleados = RRHH['ID'].nunique()

# Filtrar solo empleados con ausencias reales (horas > 0)
empleados_con_ausencia_real = RRHH[RRHH['Absenteeism_hours'] > 0]['ID'].nunique()

# Calcular el porcentaje de empleados ausentes
# ADVERTENCIA: Esto asume que el dataset incluye a todos los empleados de la empresa.
# Si no, el porcentaje no será correcto.
porcentaje_ausentes = (empleados_con_ausencia_real / total_empleados) * 100

# Mostrar los resultados
print("="*50)
print("ESTADÍSTICAS DE ABSENTISMO")
print("="*50)
print(f"Total horas absentismo anual: {total_hores_abs:.2f}")
print(f"Total empleados únicos: {total_empleados}")
print(f"✅ Porcentaje de empleados ausentes: {porcentaje_ausentes:.2f}%")
print(f"   - Empleados totales en dataset: {total_empleados}")
print(f"   - Empleados con ausencias reales: {empleados_con_ausencia_real}")

# Advertencia
if empleados_con_ausencia_real == total_empleados:
    print("\n⚠️  ADVERTENCIA: El porcentaje puede ser 100% porque el dataset solo incluye empleados con ausencias.")
    print("   Si necesitas el porcentaje sobre el total de empleados de la empresa, debes proporcionar el total de empleados.")
else:
    print(f"\nNota: El cálculo asume que el dataset incluye a todos los empleados de la empresa.")
    print(f"      Empleados sin ausencias en el dataset: {total_empleados - empleados_con_ausencia_real}")

print("="*50)
# Out:
# ==================================================
# ESTADÍSTICAS DE ABSENTISMO
# ==================================================
# Total horas absentismo anual: 5856.00
# Total empleados únicos: 136
# ✅ Porcentaje de empleados ausentes: 94.85%
#    - Empleados totales en dataset: 136
#    - Empleados con ausencias reales: 129
#
# Nota: El cálculo asume que el dataset incluye a todos los empleados de la empresa.
#       Empleados sin ausencias en el dataset: 7
# ==================================================

# %% [markdown]
# 2. Mes pico de carga por ausencias:
# El mes con la maxima suma de horas de absentismo

# %%
# Agrupar por mes y sumar las horas de absentismo
absentismo_por_mes = RRHH.groupby('Month_absence')['Absenteeism_hours'].sum()

# Encontrar el mes con el máximo valor
mes_pico = absentismo_por_mes.idxmax()
max_horas = absentismo_por_mes.max()

print(f"El mes pico de carga por ausencias es {mes_pico} con {max_horas} horas de absentismo.")
# Out:
# El mes pico de carga por ausencias es Marzo con 861.0 horas de absentismo.

# %% [markdown]
# 3. Motivo modal de absentismo laboral:
# Maxima frequencia de motivo de ausencia

# %%
# Calcular el motivo modal de absentismo
motivo_modal = RRHH['Reason_absence'].mode()[0]
frecuencia_modal = RRHH['Reason_absence'].value_counts().max()

# Obtener la descripción del motivo modal del diccionario
descripcion_modal = reason_absence_dict.get(motivo_modal, "Motivo desconocido")

# Imprimir el resultado
print(f"El motivo modal de absentismo es: {descripcion_modal} (Código: {motivo_modal})")
print(f"Frecuencia: {frecuencia_modal} ausencias")
# Out:
# El motivo modal de absentismo es: Motivo desconocido (Código: Consulta médica)
# Frecuencia: 161 ausencias

# %% [markdown]
# 4. Indice de eficencia relativa por carga laboral:
# Suma de hit target
# (DIVIDIDO ENTRE)
# Suma de work load average/day

# %%
suma_hit = RRHH['Hit_target'].sum()        # sigue siendo 0-1
suma_workload = RRHH['Work_load_Average_day'].sum()

indice_eficiencia = (suma_hit / suma_workload)
print("Índice eficiencia:", indice_eficiencia)
# Out:
# Índice eficiencia: 0.34648258668727794

# %% [markdown]
# 2. Mes pico de carga por ausencias:
# El mes con la maxima suma de horas de absentismo

# %%
# Agrupar por mes y sumar las horas de absentismo
absentismo_por_mes = RRHH.groupby('Month_absence')['Absenteeism_hours'].sum()

# Encontrar el mes con el máximo valor
mes_pico = absentismo_por_mes.idxmax()
max_horas = absentismo_por_mes.max()

print(f"El mes pico de carga por ausencias es {mes_pico} con {max_horas} horas de absentismo.")
# Out:
# El mes pico de carga por ausencias es Marzo con 861.0 horas de absentismo.

# %% [markdown]
# 3. Motivo modal de absentismo laboral:
# Maxima frequencia de motivo de ausencia

# %%
# Calcular el motivo modal de absentismo
motivo_modal = RRHH['Reason_absence'].mode()[0]
frecuencia_modal = RRHH['Reason_absence'].value_counts().max()

# Obtener la descripción del motivo modal del diccionario
descripcion_modal = reason_absence_dict.get(motivo_modal, "Motivo desconocido")

# Imprimir el resultado
print(f"El motivo modal de absentismo es: {descripcion_modal} (Código: {motivo_modal})")
print(f"Frecuencia: {frecuencia_modal} ausencias")
# Out:
# El motivo modal de absentismo es: Motivo desconocido (Código: Consulta médica)
# Frecuencia: 161 ausencias

# %% [markdown]
# 4. Indice de eficencia relativa por carga laboral:
# Suma de hit target
# (DIVIDIDO ENTRE)
# Suma de work load average/day

# %%
suma_hit = RRHH['Hit_target'].sum()        # sigue siendo 0-1
suma_workload = RRHH['Work_load_Average_day'].sum()

indice_eficiencia = (suma_hit / suma_workload)
print("Índice eficiencia:", indice_eficiencia)
# Out:
# Índice eficiencia: 0.34648258668727794
